# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpit07/DeepLearning_CFC/blob/main/DL_BasicDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=10000, centers=2, random_state=42)

# %%
sns.scatterplot(X[:, 0], X[:, 1], hue=y)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
y_mod = y.reshape(-1, 1)

# %%
y_mod.shape
# Out:
# (10000, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()
d1 = Dense(units=1, activation="sigmoid", input_shape=(2,))
model.add(d1)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.33, random_state=42)

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.fit(X_train, y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 0.9975
# Epoch 2/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 0.9988
# Epoch 3/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0148 - accuracy: 0.9993
# Epoch 4/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 0.9993
# Epoch 5/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 0.9996
# Epoch 6/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 0.9996
# Epoch 7/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.9996
# Epoch 8/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 0.9997
# Epoch 9/10
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 0.9997
# Epoch 10/10
# ...

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.004155612550675869, 1.0]
